# %% [markdown]
# <a href="https://colab.research.google.com/github/ManasviEmmadi/ML_AI_Projects/blob/main/opencv_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('/content/blue bus.PNG')

# %%
# !ls
# Out:
# 'blue bus.PNG'	 sample_data

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (339, 710, 3)

# %%
plt.imshow(image)

# %%
# Image preprocessing

# %%
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)

# %%
r,g,b=cv2.split(new_image)
print('r',r.shape)
print('g',g.shape)
print('b',b.shape)
# Out:
# r (339, 710)
# g (339, 710)
# b (339, 710)

# %%
new_image = cv2.merge((r,g,b))

# %%
s = 10 #s=scale
w = int(new_image.shape[1]*s/100) #doubt
h = int(new_image.shape[0]*s/100)
dim = (w,h)
re_size = cv2.resize(new_image, dim, interpolation = cv2.INTER_AREA)
re_size.shape
# Out:
# (33, 71, 3)

# %%
from PIL.Image import ROTATE_90
(h,w) = new_image.shape[:2]
c = (w/2, h/2)
angle = 90
m = cv2.getRotationMatrix2D(c,angle, 1.0)
ROTATE_90 = cv2.warpAffine(new_image, m, (h,w))

# %%
plt.imshow(ROTATE_90)
